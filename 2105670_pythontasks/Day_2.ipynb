# %% [markdown]
# ## Day 2 tasks:

# %%
import numpy as np
import matplotlib.pyplot as plt
height = np.random.normal(140, 20, 1000)
plt.figure(dpi=200)
plt.title("Height distribution")
plt.xlabel("Height(cm)")
plt.ylabel("Frequency")
plt.hist(height, bins=30, ec="white")
# Out:
# (array([ 3.,  4.,  2.,  6., 12., 16., 15., 31., 45., 41., 63., 51., 78.,
#         83., 66., 70., 73., 66., 68., 56., 47., 33., 22., 17., 11.,  8.,
#          5.,  2.,  4.,  2.]),
#  array([ 80.91025729,  84.90210565,  88.89395401,  92.88580237,
#          96.87765073, 100.86949909, 104.86134745, 108.85319581,
#         112.84504417, 116.83689253, 120.82874089, 124.82058925,
#         128.81243761, 132.80428597, 136.79613433, 140.78798269,
#         144.77983105, 148.77167941, 152.76352777, 156.75537613,
#         160.74722449, 164.73907285, 168.73092121, 172.72276958,
#         176.71461794, 180.7064663 , 184.69831466, 188.69016302,
#         192.68201138, 196.67385974, 200.6657081 ]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# **Difference between interpreter and compiler?**
#
# Compiler considers the entire program as a whole and translates the entire source code in one run whereas Interpreter translates the source code line by line.

# %% [markdown]
# **What is Data Structure, why we need one in programs?**
#
# Data structures is a way to organise data stored in a computer in an efficient manner such that the retrival and storage of data from those structures becomes easy.
